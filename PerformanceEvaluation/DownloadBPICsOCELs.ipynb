# %%
import urllib.request
import zipfile
import os

# %%
def download_ocel(url,output_path):
    # URL and output path

    # Ensure directory exists
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    # Download ZIP
    print("Downloading...")
    urllib.request.urlretrieve(url, output_path)
    print(f"Downloaded to {output_path}")

    # Unzip into same folder
    extract_dir = os.path.dirname(output_path)

    print("Extracting...")
    with zipfile.ZipFile(output_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)

    print(f"Extracted into {extract_dir}")

# %%
url = "https://data.4tu.nl/file/7d097cec-7304-4b85-9e78-a3ca1cc44c40/cc0054bd-c4df-4f0b-8b47-b54c0721cdb3"
output_path = "./data/BPIC2014.zip"

download_ocel(url,output_path)
# Out:
# Downloading...
# Downloaded to ./data/BPIC2014.zip
# Extracting...
# Extracted into ./data

# %%
url = "https://data.4tu.nl/file/95613fb2-29a5-49dc-b196-0948cf96cd7c/16c2f8c1-dbb3-4c15-ad64-6a5333fdee10"
output_path = "./data/BPIC2016.zip"

download_ocel(url,output_path)
# Out:
# Downloading...
# Downloaded to ./data/BPIC2016.zip
# Extracting...
# Extracted into ./data

# %%
url = "https://data.4tu.nl/file/6889ca3f-97cf-459a-b630-3b0b0d8664b5/5d5b9f89-7fa6-4c92-b6ac-04f854bdf92e"
output_path = "./data/BPIC2017.zip"

download_ocel(url,output_path)
# Out:
# Downloading...
# Downloaded to ./data/BPIC2017.zip
# Extracting...
# Extracted into ./data

# %%
url = "https://data.4tu.nl/file/46a7e15b-10c7-4ab2-988d-ee67d8ea515a/ae11f6ca-2824-407d-98ea-ec8bc456e714"
output_path = "./data/BPIC2019.zip"

download_ocel(url,output_path)
# Out:
# Downloading...
# Downloaded to ./data/BPIC2019.zip
# Extracting...
# Extracted into ./data
